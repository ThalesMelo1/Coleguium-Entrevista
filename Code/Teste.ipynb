# %%
import pandas as pd

df1 = pd.read_csv('/workspaces/Coleguium-Entrevista/Data/case_-_assistente_de_dados.xlsx - Base de matriculados.csv')
df2 = pd.read_csv('/workspaces/Coleguium-Entrevista/Data/case_-_assistente_de_dados.xlsx - Base de Inscritos.csv')

# %%
df1
# Out:
#                         Unidade Código Candidato                Turma  Turno  \
# 0      Conceição do Mato Dentro           CL8055             1ª Série  Manhã
# 1                   Lagoa Santa           CL5856             1ª Série  Manhã
# 2                  Santa Amélia          CL23605             1ª Série  Manhã
# 3                       Jaraguá          CL15909             1ª Série  Manhã
# 4                 Carlos Prates           CL8476             1ª Série  Manhã
# ...                         ...              ...                  ...    ...
# 10335          Mais Cidade Nova          CL17039  Infantil 5 Bilíngue  Tarde
# 10336          Mais Cidade Nova           CL5831  Infantil 5 Bilíngue  Tarde
# 10337            Mais Belvedere          CL11980  Infantil 5 Bilíngue  Tarde
# 10338              Mais Buritis          CL14438  Infantil 5 Bilíngue  Tarde
# 10339             Mais Pampulha          CL11383  Infantil 5 Bilíngue  Tarde
#
# ...

# %%
df2
# Out:
#                         Unidade                Série Código Candidato  \
# 0                    Ouro Preto             3ª série           CL0001
# 1      Conceição do Mato Dentro           Infantil 4           CL0002
# 2                       Buritis  Infantil 5 bilíngue           CL0003
# 3                   Cidade Nova      1º ano bilíngue           CL0004
# 4                    Nova Suiça               3º ano           CL0005
# ...                         ...                  ...              ...
# 25393                   Jaraguá             2ª série          CL25394
# 25394                   Castelo               2º ano          CL25395
# 25395            Alípio de Melo               1º ano          CL25396
# 25396         Gutierrez - EF/EM               1º ano          CL25397
# 25397            Alípio de Melo             3ª série          CL25398
#
#          Data de Inscrição            Tipo
# 0      18/08/2024 22:46:00     Rematrícula
# ...
